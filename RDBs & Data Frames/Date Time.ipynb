# %%
# Importing the lybraries
from pyspark.sql.functions import *
from pyspark.sql.types import *
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Let´s create dataframes as strings
df_data_1 = spark.createDataFrame(['2018-01-01 00:00:00+00:00', '2018-07-05 01:00:00+00:00','2018-09-06 02:00:00+00:00'], "string").toDF("dates")
df_data_2 = spark.createDataFrame(['2017-12-31 16:00:00', '2017-12-15 17:00:00','2017-12-05 18:00:00'], "string").toDF("dates")
df_data_3 = spark.createDataFrame(['2018-02-01', '2018-11-18', '2018-12-03'], "string").toDF("dates")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Displaying our DFs
display(df_data_1)
display(df_data_2)
display(df_data_3)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dates</th></tr></thead><tbody><tr><td>2018-01-01 00:00:00+00:00</td></tr><tr><td>2018-07-05 01:00:00+00:00</td></tr><tr><td>2018-09-06 02:00:00+00:00</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df_data_1.createOrReplaceTempView("date_1")
df_data_2.createOrReplaceTempView("date_2")
df_data_3.createOrReplaceTempView("date_3")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT
  TO_TIMESTAMP(dates) dates
FROM date_1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dates</th></tr></thead><tbody><tr><td>2018-01-01T00:00:00.000+0000</td></tr><tr><td>2018-07-05T01:00:00.000+0000</td></tr><tr><td>2018-09-06T02:00:00.000+0000</td></tr></tbody></table></div>

# %%
df_sql_data_1 = df_data_1

df_sql_data_1 = spark.sql("""
  SELECT
    TO_TIMESTAMP(dates) dates
  FROM date_1
""")
df_sql_data_1.display()

df_sql_data_2 = df_data_2

df_sql_data_2 = spark.sql("""
  SELECT
    CAST(dates AS DATE) dates
  FROM date_2
""")
df_sql_data_2.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dates</th></tr></thead><tbody><tr><td>2018-01-01T00:00:00.000+0000</td></tr><tr><td>2018-07-05T01:00:00.000+0000</td></tr><tr><td>2018-09-06T02:00:00.000+0000</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
SELECT
  --TO_DATE(dates,"yyyy-MM-dd") date_brazil
  TO_TIMESTAMP(dates,"yyyy-MM-dd") timestamp_brazil
FROM date_3
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>timestamp_brazil</th></tr></thead><tbody><tr><td>2018-02-01T00:00:00.000+0000</td></tr><tr><td>2018-11-18T00:00:00.000+0000</td></tr><tr><td>2018-12-03T00:00:00.000+0000</td></tr></tbody></table></div>

# %%
df_spark_data_1 = df_data_1
df_spark_data_1 = df_spark_data_1.withColumn( "dates", to_timestamp("dates") ) 
df_spark_data_1.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- dates: timestamp (nullable = true)
#
# </div>

# %%
df_spark_data_2 = df_data_2
df_spark_data_2 = df_spark_data_2.withColumn("dates" , to_date("dates"))
df_spark_data_2.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- dates: date (nullable = true)
#
# </div>

# %%
df_spark_data_3 = df_data_3
df_spark_data_3 = df_spark_data_3.withColumn("dates" , to_date("dates" , "yyyy-MM-dd"))
df_spark_data_3.display()
df_spark_data_3.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dates</th></tr></thead><tbody><tr><td>2018-02-01</td></tr><tr><td>2018-11-18</td></tr><tr><td>2018-12-03</td></tr></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- dates: date (nullable = true)
#
# </div>
